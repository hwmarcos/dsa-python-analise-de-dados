# %%
import bokeh
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, output_file
from bokeh.models import ColumnDataSource
from bokeh.transform import factor_cmap
from bokeh.palettes import Spectral6

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4e9ebfa0-88d7-4046-97c2-e0bd130ebc7a">Loading BokehJS ...</span>
#     </div>

# %%
output_file('bokeh01.html')

# %%
p = figure()
p.line([1,2,3,4,5], [6,7,4,19,1], line_width=2)
# Out:
# GlyphRenderer(id='de674333-8674-4ca5-ae9f-57a7cfd75e12', ...)

# %%
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="65ca2f1c-c3cf-44c7-ab59-c36e8cea8d68"></div>
# </div>
