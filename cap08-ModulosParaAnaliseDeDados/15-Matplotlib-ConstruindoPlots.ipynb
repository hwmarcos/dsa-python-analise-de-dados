# %%
import matplotlib as mtl
import matplotlib.pyplot as plt

# %%
mtl.__version__
# Out:
# '2.1.2'

# %%
plt.plot([1,3,5], [7,9,18])

# %%
x = [100, 101, 189, 222]

# %%
y = [3, 7, 4, 2]

# %%
plt.ylabel('valor 1')
plt.xlabel('valor 2')
plt.title('Título PLOT')
plt.plot(x,y)
plt.show()
